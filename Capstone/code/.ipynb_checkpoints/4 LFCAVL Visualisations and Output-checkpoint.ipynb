# %%
#Base
import sys
import seaborn as sns
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import time
import pickle
import datetime as dt
from datetime import datetime
from datetime import date
import json
import requests
import emoji
import re
import string
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('../datasets/avlliv_sentiment.csv', converters = {'tokens': eval, 'sentiment_dict':eval})

# %%
df.head()
# Out:
#               date            user  is_retweet  is_quote  \
# 0  4/10/2020 18:10    justincroser       False     False
# 1  4/10/2020 18:10      LFCYNWA125        True     False
# 2  4/10/2020 18:10  itstugenfinest        True     False
# 3  4/10/2020 18:10     guu_mendees        True     False
# 4  4/10/2020 18:10   justindivine5        True      True
#
#                                                 text  \
# 0  come on reds!! 🔴🔴 have to sleep for work but h...
# 1  rt @lfc: jürgen klopp provides detail on the s...
# 2  rt @skysportspl: 'i'm pretty sure he won't be ...
# 3  rt @ludovicofans: now follow the news        l...
# 4  rt @anfieldwatch: jurgen klopp: “it’s an inter...
#
#                                          quoted_text  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Liverpool face an anxious wait on how long the...
#
#                      mentions                                    hashtags  \
# 0                         NaN  ['#AVLLIV', '#LFC', '#LFCFamily', '#YNWA']
# 1  ['@LFC', '@Alissonbecker']                         ['#LFC', '#AVLLIV']
# 2            ['@SkySportsPL']                                         NaN
# 3           ['@ludovicofans']                                         NaN
# 4           ['@AnfieldWatch']                                         NaN
#
#                                            cleantext  lang  \
# 0  come on reds have to sleep for work but hoping...     1
# 1  username jrgen klopp provides detail on the sh...     1
# 2  username im pretty sure he wont be ready after...     1
# 3  username now follow the news live live streami...     1
# 4  username jurgen klopp its an international bre...     1
#
#                                               tokens             datetime  \
# 0  [come, red, sleep, work, hope, win, go, watch,...  2020-10-04 18:10:00
# 1  [username, detail, shoulder_injury, sideline, ...  2020-10-04 18:10:00
# 2  [username, pretty, sure, ready, set, week, sid...  2020-10-04 18:10:00
# 3  [username, follow, news, live, live, streaming...  2020-10-04 18:10:00
# 4  [username, jurgen, klopp, pretty, sure, ready,...  2020-10-04 18:10:00
#
#        time                                     sentiment_dict  \
# 0  18:10:00  {'neg': 0.0, 'neu': 0.729, 'pos': 0.271, 'comp...
# 1  18:10:00  {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'comp...
# 2  18:10:00  {'neg': 0.079, 'neu': 0.714, 'pos': 0.207, 'co...
# 3  18:10:00  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4  18:10:00  {'neg': 0.074, 'neu': 0.734, 'pos': 0.192, 'co...
#
#    sentiment_score sentiment_rating
# 0           0.8720              pos
# 1          -0.4215              neg
# 2           0.5252              pos
# 3           0.0000              neu
# 4           0.5252              pos

# %%
df['datetime']=pd.to_datetime(df['datetime'])

# %%
matchmask = (df['datetime'] >= datetime.strptime('2020-10-04 18:15:00','%Y-%m-%d %H:%M:%S')) & (df['datetime'] <= datetime.strptime('2020-10-04 20:09:00','%Y-%m-%d %H:%M:%S'))

# %% [markdown]
# # Tweets per minute

# %% [markdown]
# # Wordcount processing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 207727 entries, 0 to 207726
# Data columns (total 13 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   date         207727 non-null  object
#  1   user         207727 non-null  object
#  2   is_retweet   207727 non-null  bool
#  3   is_quote     207727 non-null  bool
#  4   text         207727 non-null  object
#  5   quoted_text  19722 non-null   object
#  6   mentions     125645 non-null  object
#  7   hashtags     44217 non-null   object
#  8   cleantext    207727 non-null  object
#  9   lang         207727 non-null  int64
#  10  tokens       207727 non-null  object
#  11  datetime     207727 non-null  object
#  12  time         207727 non-null  object
# dtypes: bool(2), int64(1), object(10)
# memory usage: 19.4+ MB

# %%
terms = pd.read_csv('../datasets/avlliv_terms.csv')

# %%
terms.head()
# Out:
#               datetime      time tokens
# 0  2020-10-04 18:10:00  18:10:00   come
# 0  2020-10-04 18:10:00  18:10:00    red
# 0  2020-10-04 18:10:00  18:10:00  sleep
# 0  2020-10-04 18:10:00  18:10:00   work
# 0  2020-10-04 18:10:00  18:10:00   hope

# %%
terms['datetime']=pd.to_datetime(terms['datetime'])

# %%
def find_lol(text):
    try:
        text = re.findall(r'\b(o?l+o+l+[ol]*)\b', text)
        if not text:
            text = np.NaN
    except:
        pass
    return text

# %%
lols = terms['tokens'].apply(find_lol)

# %%
lols.explode().value_counts()
# Out:
# lol                1373
# loool               103
# looool               64
# loooool              63
# lool                 61
# looooool             37
# loooooool            20
# loooooooool          10
# looooooool            8
# looooooooool          6
# lolol                 6
# loll                  5
# loooooooooooool       4
# lollll                3
# lolll                 3
# lololol               3
# loooooooooool         3
# loooollll             2
# lolllllll             1
# looooollll            1
# lolololol             1
# looooooooooool        1
# looololololol         1
# lolololo              1
# lolllll               1
# lollllll              1
# loooooooooll          1
# lolololololol         1
# lololololololol       1
# loooolll              1
# looooooooooll         1
# Name: tokens, dtype: int64

# %%
def find_swears(text):
    try:
        text = re.findall(r'\b(f+u+c+k+)\b', text)
        if not text:
            text = np.NaN
    except:
        pass
    return text

# %%
swears = terms['tokens'].apply(find_swears)

# %%
swears.explode().value_counts()
# Out:
# fuck           2618
# fuckkkkkkk       53
# fuckkk            3
# fuckkkk           3
# fuckkkkk          2
# fuckkkkkk         2
# fuckk             1
# fuckkkkkkkk       1
# fuuuuuuuck        1
# Name: tokens, dtype: int64

# %%
def laughter(text):
    try:
        text= re.sub(r'\b(a*ha+h[ha]*)\b', 'haha', text)
        text= re.sub(r'\b(o?l+o+l+[ol]*)\b', 'lol', text)
        text= re.sub(r'\b(l+m+a+o+)\b', 'fuck', text)
    except:
        pass
    return text

# %%
def swearing(text):
    try:
        text= re.sub(r'\b(f+u+c+k+)\b', 'fuck', text)
        text= re.sub(r'\b(w+t+f+)\b', 'wtf', text)
    except:
        pass
    return text

# %%
terms['tokens'] = terms['tokens'].apply(laughter).apply(swearing)

# %% [markdown]
# # Setting labels

# %%
# Annotate each of the goals on the xticks
match_x_labels =['', 'Kick Off 0', '', '', '',
       'Watkins Goal 4', '', '', '', '',
       '', '', '', '', '',
       '', '', '', '', '',
       '', '', '', 'Watkins Goal 22', '',
       '', '', '', '', '',
       '', '', '', '', 'Salah Goal 33',
       '', 'McGinn Goal 35', '', '', '',
       'Watkins Goal 39', '', '', '', '',
       '', '', '', '', 'Half Time 45+3',
       '', '', '', '', '',
       '', '', '', '', '',
       '', '', '', '', '',
       '', 'Second Half 45', '', '', '',
       '', '', '', '', '',
       '', 'Barkley 55', '', '', '',
       '', 'Salah Goal 60', '', '', '',
       '', 'Grealish Goal 66', '', '', '',
       '', '', '', '', '',
       '', '', 'Grealish 75', '', '',
       '', '', '', '', '',
       '', '', '', '', '',
       '', '', '', '', 'Full Time 90+3']

# %%
# The laughs mask is missing 2 values, so the lables are adjusted accordingly
matchlol_x_labels =['', 'Kick Off 0', '',
       'Watkins Goal 4', '', '', '', '',
       '', '', '', '', '',
       '', '', '', '', '',
       '', '', '', 'Watkins Goal 22', '',
       '', '', '', '', '',
       '', '', '', '', 'Salah Goal 33',
       '', 'McGinn Goal 35', '', '', '',
       'Watkins Goal 39', '', '', '', '',
       '', '', '', '', 'Half Time 45+3',
       '', '', '', '', '',
       '', '', '', '', '',
       '', '', '', '', '',
       '', 'Second Half 45', '', '', '',
       '', '', '', '', '',
       '', 'Barkley 55', '', '', '',
       '', 'Salah Goal 60', '', '', '',
       '', 'Grealish Goal 66', '', '', '',
       '', '', '', '', '',
       '', '', 'Grealish 75', '', '',
       '', '', '', '', '',
       '', '', '', '', '',
       '', '', '', '', 'Full Time 90+3']

# %% [markdown]
# # There was laughter

# %%
lolmask = (terms['datetime'] >= datetime.strptime('2020-10-04 18:15:00','%Y-%m-%d %H:%M:%S')) & (terms['datetime'] <= datetime.strptime('2020-10-04 20:09:00','%Y-%m-%d %H:%M:%S')) & (terms['tokens'] == 'lol')

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x=terms[lolmask]['time'])
ax.set_xticklabels(matchlol_x_labels, rotation = 45, ha='right',fontsize=11)
plt.show()

# %%
plt.figure(figsize=(15,8))
ax = sns.countplot(x=terms[lolmask]['time'])
ax.set_xticklabels(matchlol_x_labels, rotation = 45, ha='right',fontsize=11)
plt.show()

# %% [markdown]
# # And there was anger

# %%
swearmask = (terms['datetime'] >= datetime.strptime('2020-10-04 18:15:00','%Y-%m-%d %H:%M:%S')) & (terms['datetime'] <= datetime.strptime('2020-10-04 20:09:00','%Y-%m-%d %H:%M:%S')) & ((terms['tokens'] == 'wtf') | (terms['tokens'] == 'fuck'))

# %%
plt.figure(figsize=(15,9))
ax = sns.countplot(x=terms[swearmask]['time'],hue=terms[swearmask]['tokens'])
#[l.set_visible(False) for (i,l) in enumerate(ax.xaxis.get_ticklabels()) if i % 10 != 0]
ax.set_xticklabels(match_x_labels, rotation = 45, ha='right')
plt.show()

# %% [markdown]
# # Number of mentions

# %%
def add_mentions(text):
    mentionlist = re.findall(r'\B@\w+', text)
    if not mentionlist:
        mentionlist = np.NaN
    return mentionlist
df['mentions'] = df['text'].apply(add_mentions)

# %%
mentioncount = df['mentions'].explode('mentions').value_counts()[:20]

# %%
plt.figure(figsize=(12,5))
sns.barplot(mentioncount.values, mentioncount.index, alpha=0.8)
plt.title('20 Most Mentioned Accounts')
plt.ylabel('Nº of Mentions', fontsize=12)
plt.xlabel('Account', fontsize=12)
plt.show()

# %% [markdown]
# Nigerian scams?

# %%
demo.loc[demo['mentions']== '@nigerianscamsss'].text.unique()
# Out:
# array(['@nigerianscamsss you need to be crying about your club. don’t let liverpool’s loss change the fact your club is in bottom half of the table',
#        'rt @nigerianscamsss: aston villa are giving me sustenance',
#        'rt @nigerianscamsss: 5-1 aston villa.  oluwaross barkley. https://t.co/crmrigtmtv',
#        'rt @nigerianscamsss: liverpool doesn’t have a red card',
#        'rt @nigerianscamsss: man city took 5. man utd took 6. liverpool are taking 5. https://t.co/1no0rvqpxh',
#        'rt @nigerianscamsss: liverpool told man utd you will never walk alone.',
#        'rt @nigerianscamsss: nah 7 against aston villa  with 11 men on the pitch?!',
#        'beat that snake😂😂😂😂 just beat it it  🎶🎶,i had just slept for like two minutes only to find 6-2 for the liverpool game what is not happening 🤣🤣🤣🤣🤣\r\n2020-10-04 19:52:23,crfmiller1,false,true,kkkkkkkkkkkkkkkkk que loucura,gol do aston villa! grealish!  aston villa 7-2 liverpool!\r\n2020-10-04 19:52:23,tobinho05,false,false,no sadio  no liverpool sadio is the real mvp💯,\r\n2020-10-04 19:52:23,mrsocratez,false,false,main 11 org lawan aston villa kena 7 lagi terok dari man u kahkahkah,\r\n2020-10-04 19:52:23,alexand38123940,true,false,rt @futbolbible: oooooooooh my godddddddddddddddd what the fuckkkkkkk is going onnnnnnnnnn????????????? this is one of the weirdest games i…,\r\n2020-10-04 19:52:23,sthezozo,false,false,what a great soccer day. man u and liverpool in 6s and 7s.  #astliv,\r\n2020-10-04 19:52:23,do_i_look_high,true,false,rt @avfcofficial: number seven!!!! 🤯  \U0001f7e3 7-2 ⚫ #avlliv https://t.co/tkanvqiabo,\r\n2020-10-04 19:52:23,arsenalolo,false,false,liverpool with sadio mane vs liverpool without him.  #astonvillaliverpool 7-2 #avlliv  #premierleague,\r\n2020-10-04 19:52:23,thomastparker,false,false,seveeeeeeen   #avfc https://t.co/ugtjtkxjzr,\r\n2020-10-04 19:52:23,mjshoultz,false,true,i cannot comprehend what is happening but gotta love it!,number seven!!!! 🤯  \U0001f7e3 7-2 ⚫ #avlliv https://t.co/tkanvqiabo\r\n2020-10-04 19:52:23,edsonsm_,false,false,olá @thalhoferjoao @ribasrrn td certo no villa park?,\r\n2020-10-04 19:52:23,jayy_vee3,true,false,rt @footballfactly: 04\': aston villa 1-0 liverpool 22\': aston villa 2-0 liverpool 33\': aston villa 2-1 liverpool 35\': aston villa 3-1 liver…,\r\n2020-10-04 19:52:23,team_macol,false,false,@maziibe_ liverpool is happening 😂😂🤣,\r\n2020-10-04 19:52:23,fausrrodriguez,false,false,no te puede meter 7 el aston villa,\r\n2020-10-04 19:52:23,joaovpiress,false,false,villa destruindo 🔥🔥🔥🔥,\r\n2020-10-04 19:52:23,azthornhill3,true,false,rt @bootleggerooc: liverpool fans to adrian #avlliv https://t.co/nghpnbvwum,\r\n2020-10-04 19:52:23,joebaileyutb,true,false,rt @premierleague: goal aston villa 7-2 liverpool (75 mins)  what a day for aston villa! jack grealish gets his second from john mcginn\'s c…,\r\n2020-10-04 19:52:23,jx11den,true,false,rt @lfc: goal. #avfc.  [3-1]  #lfc | #avlliv,\r\n2020-10-04 19:52:24,hugomoyasno,false,false,al liverpool le deben guita desde noviembre sino no se entiende,\r\n2020-10-04 19:52:24,adzzcfc,true,false,rt @lfc: goal. #avfc.   [7-2]  #lfc | #avlliv,\r\n2020-10-04 19:52:24,frdausx_,true,false,rt @squawkanews: aston villa have scored seven against liverpool.,\r\n2020-10-04 19:52:24,foxy_james,false,false,villa are winning the league heard it hear 1st,\r\n2020-10-04 19:52:24,footiexmadx,false,true,wow 😂😂😂😂😂,goal. #avfc.   [7-2]  #lfc | #avlliv\r\n2020-10-04 19:52:24,flybyknite,false,false,aston villa this season is basically what richmond fc will be on ted lasso in season two.,\r\n2020-10-04 19:52:24,kknowsg,false,false,i\'d be 6 2 my stomach if that was my team tbh. #liverpool,\r\n2020-10-04 19:52:24,lungisani__,false,true,😭😭😭😭😭😭😭😭,mane tested positive but it is liverpool battling a pandemic\r\n2020-10-04 19:52:24,manggalaxiv,false,false,@idextratime liverpool ini kenapa sih cok :v,\r\n2020-10-04 19:52:24,cameronyardejnr,false,true,the game\'s gone! what a performance!,aston villa have scored seven against liverpool.\r\n2020-10-04 19:52:24,okoeborlouis,true,true,rt @tolumhen: speak up weyrey. who dey chop 6?,goal. #avfc.  [6-2]  #lfc | #avlliv\r\n2020-10-04 19:52:24,hxyy986,false,false,plus jamais avec un maillot de liverpool tu me pourris la vie la con de toi @adrisanmiguel,\r\n2020-10-04 19:52:24,kayoladapo,true,false,rt @trollfootball: how many goals did villa score against liverpool  jürgen?  https://t.co/w3myopinns,\r\n2020-10-04 19:52:24,stebbi85,false,false,og þeir eru búnir að skora 7! get rifið kjaft  united fékk ekki 7 á sig 😂😂 eru þetta ensku meistararnir 😂😂😂 verstu meistarar sögunnar?  hvaða meistaralið fær á sig 7 frá fallbarátt ...
#        '@nigerianscamsss i know allison is out for liverpool but seven???',
#        'rt @nigerianscamsss: aston villa should score 8.  arsenal fans need love too.',
#        'rt @nigerianscamsss: with adrian in goal  liverpool can say things are a little... rocky',
#        'rt @nigerianscamsss: oh my god',
#        'rt @nigerianscamsss: oh my god https://t.co/yl0s3wf9sl'],
#       dtype=object)

# %% [markdown]
# # Number of hashtags

# %%
def add_hashtags(text):
    hashtaglist = re.findall(r'\B(\#[a-zA-Z0-9]+\b)',text)
    if not hashtaglist:
        hashtaglist = np.NaN
    return hashtaglist
df['hashtags'] = df['text'].apply(add_hashtags)

# %%
df['hashtags'].explode('hashtags').value_counts().head(20)
# Out:
# #avlliv           25146
# #lfc               7942
# #avfc              5251
# #liverpool         2440
# #astliv            2404
# #fpl               1646
# #premierleague     1153
# #muntot            1063
# #pl                 902
# #ynwa               811
# #astonvilla         729
# #mufc               726
# #utv                578
# #avllfc             552
# #mantot             519
# #a                  511
# #epl                491
# #villa              363
# #manutd             331
# #livestream         329
# Name: hashtags, dtype: int64

# %%
hashtagcount = df['hashtags'].explode('hashtags').value_counts()[:20]

# %%
plt.figure(figsize=(12,5))
sns.barplot(hashtagcount.values, hashtagcount.index, alpha=0.8)
plt.title('20 Most Used Hashtags')
plt.ylabel('Nº of hashtags', fontsize=12)
plt.xlabel('Hashtag', fontsize=12)
plt.show()

# %% [markdown]
# # Average sentiment of tweets

# %%
df.groupby('time')['sentiment_score'].mean()
# Out:
# time
# 18:10:00    0.246791
# 18:11:00    0.233308
# 18:12:00    0.263488
# 18:13:00    0.162777
# 18:14:00    0.261291
#               ...
# 20:16:00    0.098029
# 20:17:00    0.102446
# 20:18:00    0.121415
# 20:19:00    0.129688
# 20:20:00    0.135914
# Name: sentiment_score, Length: 131, dtype: float64

# %% [markdown]
# # Sentiment polarity of tweets

# %%
df
# Out:
#                    date             user  is_retweet  is_quote  \
# 0       4/10/2020 18:10     justincroser       False     False
# 1       4/10/2020 18:10       LFCYNWA125        True     False
# 2       4/10/2020 18:10   itstugenfinest        True     False
# 3       4/10/2020 18:10      guu_mendees        True     False
# 4       4/10/2020 18:10    justindivine5        True      True
# ...                 ...              ...         ...       ...
# 207722  4/10/2020 20:20  notbitterbetter       False     False
# 207723  4/10/2020 20:20        artDante1       False     False
# 207724  4/10/2020 20:20         jonesy73       False     False
# 207725  4/10/2020 20:20         ryanYNWA        True     False
# 207726  4/10/2020 20:20            A93ii        True     False
#
#                                                      text  \
# 0       come on reds!! 🔴🔴 have to sleep for work but h...
# 1       rt @lfc: jürgen klopp provides detail on the s...
# 2       rt @skysportspl: 'i'm pretty sure he won't be ...
# 3       rt @ludovicofans: now follow the news        l...
# 4       rt @anfieldwatch: jurgen klopp: “it’s an inter...
# ...                                                   ...
# 207722  villa were poor there  should’ve scored 10 or 11.
# 207723  good time to be alive...  manchester united lo...
# 207724  gutted that we couldn’t all be there together ...
# 207725  rt @elliothackney: everyone: last season was b...
# 207726  rt @avfcofficial: 90’ | 'we want eight!'  ...i...
#
#                                               quoted_text  \
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3                                                     NaN
# 4       Liverpool face an anxious wait on how long the...
# ...                                                   ...
# 207722                                                NaN
# 207723                                                NaN
# 207724                                                NaN
# 207725                                                NaN
# 207726                                                NaN
#
#                           mentions  \
# 0                              NaN
# 1       ['@LFC', '@Alissonbecker']
# 2                 ['@SkySportsPL']
# 3                ['@ludovicofans']
# 4                ['@AnfieldWatch']
# ...                            ...
# 207722                         NaN
# 207723                         NaN
# 207724                         NaN
# 207725          ['@ElliotHackney']
# 207726           ['@AVFCOfficial']
#
#                                           hashtags  \
# 0       ['#AVLLIV', '#LFC', '#LFCFamily', '#YNWA']
# 1                              ['#LFC', '#AVLLIV']
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
# ...                                            ...
# 207722                                         NaN
# 207723                                 ['#AVLLFC']
# 207724                                         NaN
# 207725                                         NaN
# 207726                                 ['#AVLLIV']
#
#                                                 cleantext  lang  \
# 0       come on reds have to sleep for work but hoping...     1
# 1       username jrgen klopp provides detail on the sh...     1
# 2       username im pretty sure he wont be ready after...     1
# 3       username now follow the news live live streami...     1
# 4       username jurgen klopp its an international bre...     1
# ...                                                   ...   ...
# 207722         villa were poor there shouldve scored  or      1
# 207723  good time to be alive manchester united loses ...     1
# 207724  gutted that we couldnt all be there together t...     1
# 207725  username everyone last season was boring liver...     1
# 207726  username   we want eight is what the crowd wou...     1
#
#                                                    tokens            datetime  \
# 0       [come, red, sleep, work, hope, win, go, watch,... 2020-10-04 18:10:00
# 1       [username, detail, shoulder_injury, sideline, ... 2020-10-04 18:10:00
# 2       [username, pretty, sure, ready, set, week, sid... 2020-10-04 18:10:00
# 3       [username, follow, news, live, live, streaming... 2020-10-04 18:10:00
# 4       [username, jurgen, klopp, pretty, sure, ready,... 2020-10-04 18:10:00
# ...                                                   ...                 ...
# 207722                                      [poor, score] 2020-10-04 20:20:00
# 207723  [good, time, alive, manchester, united, lose, ... 2020-10-04 20:20:00
# 207724  [gutte, could, together, enjoy, tonight, trip,... 2020-10-04 20:20:00
# 207725  [username, everyone, last, season, bore, run, ... 2020-10-04 20:20:00
# 207726      [username, eight, crowd, would, singe, right] 2020-10-04 20:20:00
#
#             time                                     sentiment_dict  \
# 0       18:10:00  {'neg': 0.0, 'neu': 0.729, 'pos': 0.271, 'comp...
# 1       18:10:00  {'neg': 0.167, 'neu': 0.833, 'pos': 0.0, 'comp...
# 2       18:10:00  {'neg': 0.079, 'neu': 0.714, 'pos': 0.207, 'co...
# 3       18:10:00  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 4       18:10:00  {'neg': 0.074, 'neu': 0.734, 'pos': 0.192, 'co...
# ...          ...                                                ...
# 207722  20:20:00  {'neg': 0.341, 'neu': 0.659, 'pos': 0.0, 'comp...
# 207723  20:20:00  {'neg': 0.184, 'neu': 0.495, 'pos': 0.321, 'co...
# 207724  20:20:00  {'neg': 0.058, 'neu': 0.676, 'pos': 0.266, 'co...
# 207725  20:20:00  {'neg': 0.113, 'neu': 0.887, 'pos': 0.0, 'comp...
# 207726  20:20:00  {'neg': 0.0, 'neu': 0.909, 'pos': 0.091, 'comp...
#
#         sentiment_score sentiment_rating
# 0                0.8720              pos
# 1               -0.4215              neg
# 2                0.5252              pos
# 3                0.0000              neu
# 4                0.5252              pos
# ...                 ...              ...
# 207722          -0.4767              neg
# 207723           0.7184              pos
# 207724           0.9169              pos
# 207725          -0.3182              neg
# 207726           0.0772              neu
#
# [207727 rows x 16 columns]

# %%
possen1 = df[matchmask].loc[df['sentiment_rating']=='pos'].groupby('time')['sentiment_score'].mean()

# %%
possen = df[matchmask].loc[df['sentiment_rating']=='pos']

# %%
possen
# Out:
# time
# 18:10:00    0.582212
# 18:11:00    0.532773
# 18:12:00    0.546259
# 18:13:00    0.551298
# 18:14:00    0.569186
#               ...
# 20:16:00    0.521603
# 20:17:00    0.505453
# 20:18:00    0.505977
# 20:19:00    0.509229
# 20:20:00    0.521384
# Name: sentiment_score, Length: 131, dtype: float64

# %%
negsen1 = df[matchmask].loc[df['sentiment_rating']=='neg'].groupby('time')['sentiment_score'].mean()

# %%
negsen = df[matchmask].loc[df['sentiment_rating']=='neg']

# %%
sns.lineplot(data=df, x='time', y='sentiment_score')
# Out:
# <AxesSubplot:xlabel='time', ylabel='sentiment_score'>

# %%
sns.lineplot(data=df, x='time', y='sentiment_score',hue='sentiment_rating')
# Out:
# <AxesSubplot:xlabel='time', ylabel='sentiment_score'>

# %%
fig,ax = plt.subplots(figsize=(15,8))
sns.lineplot(data=possen, x='time', y='sentiment_score', ax=ax, label='positive')
ax2 = ax.twinx()
sns.lineplot(data=negsen, x='time', y='sentiment_score', ax=ax2, color='r', label='negative')
ax.set_xticklabels(match_x_labels, rotation = 45, ha='right')

ax.plot(['18:19:00','18:19:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['18:37:00','18:37:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['18:48:00','18:48:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['18:50:00','18:50:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:03:00','19:03:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:20:00','19:20:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:30:00','19:30:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:35:00','19:35:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:41:00','19:41:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:50:00','19:50:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)

ax.set_ylim(0.4,0.6)
ax2.set_ylim(-0.4,-0.6)
ax.get_legend().remove()
ax2.get_legend().remove()
fig.legend(loc="upper right", bbox_to_anchor=(1,1),bbox_transform=ax.transAxes)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(15,8))
sns.lineplot(data=possen1, x=possen1.index, y=possen1.values, ax=ax, label='positive')
ax2 = ax.twinx()
sns.lineplot(data=negsen1, x=negsen1.index, y=negsen1.values, ax=ax2, color='r', label='negative')
ax.set_xticklabels(match_x_labels, rotation = 45, ha='right')

ax.plot(['18:19:00','18:19:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['18:37:00','18:37:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['18:48:00','18:48:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['18:50:00','18:50:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:03:00','19:03:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:20:00','19:20:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:30:00','19:30:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:35:00','19:35:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:41:00','19:41:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:50:00','19:50:00'], [0.4,0.6], linestyle='dashed', color='black', alpha=0.4)

ax.set_ylim(0.4,0.6)
ax2.set_ylim(-0.4,-0.6)
ax.get_legend().remove()
ax2.get_legend().remove()
fig.legend(loc="upper right", bbox_to_anchor=(1,1),bbox_transform=ax.transAxes)
plt.show()

# %%
fig,ax = plt.subplots(figsize=(15,8))
sns.lineplot(data=df[matchmask], x='time', y='sentiment_score', ax=ax, label='positive')
ax.set_xticklabels(match_x_labels, rotation = 45, ha='right')

ax.plot(['18:19:00','18:19:00'], [-1,1], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['18:37:00','18:37:00'], [-1,1], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['18:48:00','18:48:00'], [-1,1], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['18:50:00','18:50:00'], [-1,1], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:03:00','19:03:00'], [-1,1], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:20:00','19:20:00'], [-1,1], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:30:00','19:30:00'], [-1,1], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:35:00','19:35:00'], [-1,1], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:41:00','19:41:00'], [-1,1], linestyle='dashed', color='black', alpha=0.4)
ax.plot(['19:50:00','19:50:00'], [-1,1], linestyle='dashed', color='black', alpha=0.4)

ax.set_ylim(-0.1,0.4)
ax.get_legend().remove()
fig.legend(loc="upper right", bbox_to_anchor=(1,1),bbox_transform=ax.transAxes)
plt.show()

# %% [markdown]
# # Sentiment polarity of tweets by dominant topic
